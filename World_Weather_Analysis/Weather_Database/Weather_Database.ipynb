# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_disc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": weather_disc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | pandan
# Processing Record 3 of Set 1 | manyana
# Processing Record 4 of Set 1 | balabac
# Processing Record 5 of Set 1 | hokitika
# Processing Record 6 of Set 1 | san cristobal
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | nanortalik
# Processing Record 11 of Set 1 | alamosa
# Processing Record 12 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 1 | fairbanks
# Processing Record 14 of Set 1 | myaundzha
# Processing Record 15 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | bermeo
# Processing Record 19 of Set 1 | ulma
# Processing Record 20 of Set 1 | arraial do cabo
# Processing Record 21 of Set 1 | wanaka
# Processing Record 22 of Set 1 | geraldton
# Processing Record 23 of Set 1 | la tijera
# Processing Record 24 of Set 1 | henties bay
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | asau
# Processing Record 27 of Set 1 | khatanga
# Processing Record 28 of Set 1 | lompoc
# Processing Record 29 of Set 1 | el alto
# Processing Record 30 of Set 1 | chiredzi
# Processing Record 31 of Set 1 | tarakan
# Processing Record 32 of Set 1 | guerrero negro
# Processing Record 33 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 1 | hohhot
# Processing Record 37 of Set 1 | kawalu
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | ambon
# Processing Record 40 of Set 1 | bokovskaya
# Processing Record 41 of Set 1 | mujiayingzi
# Processing Record 42 of Set 1 | adrar
# Processing Record 43 of Set 1 | kizukuri
# Processing Record 44 of Set 1 | nandikotkur
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | santa maria
# Processing Record 47 of Set 1 | mufulira
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | mar del plata
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | gaoual
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | hamilton
# Processing Record 5 of Set 2 | usagara
# Processing Record 6 of Set 2 | fortuna
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 2 | platanos
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | ashland
# Processing Record 12 of Set 2 | chandbali
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | porto santo
# Processing Record 16 of Set 2 | mount gambier
# Processing Record 17 of Set 2 | avarua
# Processing Record 18 of Set 2 | melbourne
# Processing Record 19 of Set 2 | sur
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | purranque
# Processing Record 22 of Set 2 | saint-augustin
# Processing Record 23 of Set 2 | bacolod
# Processing Record 24 of Set 2 | portovelo
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | rikitea
# Processing Record 27 of Set 2 | mandera
# Processing Record 28 of Set 2 | mana
# Processing Record 29 of Set 2 | tupancireta
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | vila
# Processing Record 32 of Set 2 | provideniya
# Processing Record 33 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 2 | atambua
# Processing Record 35 of Set 2 | beaucaire
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | tuatapere
# Processing Record 38 of Set 2 | la ronge
# Processing Record 39 of Set 2 | vostok
# Processing Record 40 of Set 2 | marsh harbour
# Processing Record 41 of Set 2 | kargil
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | new norfolk
# Processing Record 44 of Set 2 | kahului
# Processing Record 45 of Set 2 | tateyama
# Processing Record 46 of Set 2 | grand gaube
# Processing Record 47 of Set 2 | alihe
# Processing Record 48 of Set 2 | bengkulu
# Processing Record 49 of Set 2 | nara
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | kollumerland
# City not found. Skipping...
# Processing Record 2 of Set 3 | buta
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | velyka lepetykha
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | puerto ayora
# Processing Record 8 of Set 3 | teguldet
# Processing Record 9 of Set 3 | pervomayskoye
# Processing Record 10 of Set 3 | aguimes
# Processing Record 11 of Set 3 | port hedland
# Processing Record 12 of Set 3 | san quintin
# Processing Record 13 of Set 3 | high rock
# Processing Record 14 of Set 3 | shashi
# Processing Record 15 of Set 3 | leningradskiy
# Processing Record 16 of Set 3 | palmer
# Processing Record 17 of Set 3 | mahajanga
# Processing Record 18 of Set 3 | vao
# Processing Record 19 of Set 3 | san patricio
# Processing Record 20 of Set 3 | ribeira grande
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | kiliya
# Processing Record 23 of Set 3 | richards bay
# Processing Record 24 of Set 3 | abiy adi
# City not found. Skipping...
# Processing Record 25 of Set 3 | san blas
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | saint anthony
# Processing Record 28 of Set 3 | port macquarie
# Processing Record 29 of Set 3 | yima
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | mogoytuy
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | cap-aux-meules
# Processing Record 34 of Set 3 | dali
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | oussouye
# Processing Record 37 of Set 3 | caledon
# Processing Record 38 of Set 3 | flinders
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | tautira
# Processing Record 42 of Set 3 | shihezi
# Processing Record 43 of Set 3 | pacific grove
# Processing Record 44 of Set 3 | kibala
# Processing Record 45 of Set 3 | zamora
# Processing Record 46 of Set 3 | iranshahr
# Processing Record 47 of Set 3 | bathsheba
# Processing Record 48 of Set 3 | karratha
# Processing Record 49 of Set 3 | mulege
# Processing Record 50 of Set 3 | nouadhibou
# Processing Record 1 of Set 4 | cherskiy
# Processing Record 2 of Set 4 | baykit
# Processing Record 3 of Set 4 | tuktoyaktuk
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | sirpur
# Processing Record 6 of Set 4 | nevers
# Processing Record 7 of Set 4 | campbell river
# Processing Record 8 of Set 4 | maniitsoq
# Processing Record 9 of Set 4 | kibungo
# Processing Record 10 of Set 4 | broome
# Processing Record 11 of Set 4 | cap malheureux
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | zolotinka
# City not found. Skipping...
# Processing Record 14 of Set 4 | antofagasta
# Processing Record 15 of Set 4 | shingu
# Processing Record 16 of Set 4 | tarutyne
# Processing Record 17 of Set 4 | dunedin
# Processing Record 18 of Set 4 | labuhan
# Processing Record 19 of Set 4 | dingle
# Processing Record 20 of Set 4 | aswan
# Processing Record 21 of Set 4 | kyaikkami
# Processing Record 22 of Set 4 | dunmore town
# Processing Record 23 of Set 4 | anadyr
# Processing Record 24 of Set 4 | avera
# Processing Record 25 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 26 of Set 4 | ilulissat
# Processing Record 27 of Set 4 | sagua la grande
# Processing Record 28 of Set 4 | port-gentil
# Processing Record 29 of Set 4 | iqaluit
# Processing Record 30 of Set 4 | tuy hoa
# Processing Record 31 of Set 4 | ahipara
# Processing Record 32 of Set 4 | jiuquan
# Processing Record 33 of Set 4 | filadelfia
# Processing Record 34 of Set 4 | viedma
# Processing Record 35 of Set 4 | samana
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | kapaa
# Processing Record 38 of Set 4 | olafsvik
# Processing Record 39 of Set 4 | inverell
# Processing Record 40 of Set 4 | karasjok
# Processing Record 41 of Set 4 | tarnow
# Processing Record 42 of Set 4 | ucluelet
# Processing Record 43 of Set 4 | lebu
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | ibra
# Processing Record 46 of Set 4 | juifang
# City not found. Skipping...
# Processing Record 47 of Set 4 | muravlenko
# Processing Record 48 of Set 4 | beringovskiy
# Processing Record 49 of Set 4 | naugachhia
# Processing Record 50 of Set 4 | taoudenni
# Processing Record 1 of Set 5 | emerald
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | polyanka
# Processing Record 4 of Set 5 | strezhevoy
# Processing Record 5 of Set 5 | merauke
# Processing Record 6 of Set 5 | gilazi
# City not found. Skipping...
# Processing Record 7 of Set 5 | beaver dam
# Processing Record 8 of Set 5 | sobradinho
# Processing Record 9 of Set 5 | prince rupert
# Processing Record 10 of Set 5 | yellowknife
# Processing Record 11 of Set 5 | port elizabeth
# Processing Record 12 of Set 5 | gimli
# Processing Record 13 of Set 5 | madang
# Processing Record 14 of Set 5 | netishyn
# Processing Record 15 of Set 5 | altay
# Processing Record 16 of Set 5 | qaanaaq
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | esperance
# Processing Record 19 of Set 5 | solenzo
# Processing Record 20 of Set 5 | tiksi
# Processing Record 21 of Set 5 | bondo
# Processing Record 22 of Set 5 | samarai
# Processing Record 23 of Set 5 | chokurdakh
# Processing Record 24 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 5 | te anau
# Processing Record 26 of Set 5 | pangkalanbuun
# Processing Record 27 of Set 5 | mangan
# Processing Record 28 of Set 5 | vila franca do campo
# Processing Record 29 of Set 5 | klaksvik
# Processing Record 30 of Set 5 | camargo
# Processing Record 31 of Set 5 | kodinsk
# Processing Record 32 of Set 5 | novopokrovka
# Processing Record 33 of Set 5 | formosa
# Processing Record 34 of Set 5 | grindavik
# Processing Record 35 of Set 5 | dikson
# Processing Record 36 of Set 5 | pevek
# Processing Record 37 of Set 5 | shalakusha
# Processing Record 38 of Set 5 | cururupu
# Processing Record 39 of Set 5 | luis correia
# Processing Record 40 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 5 | hit
# Processing Record 42 of Set 5 | san francisco
# Processing Record 43 of Set 5 | coquimbo
# Processing Record 44 of Set 5 | luderitz
# Processing Record 45 of Set 5 | bogdana
# Processing Record 46 of Set 5 | yulara
# Processing Record 47 of Set 5 | presidente medici
# Processing Record 48 of Set 5 | maloyaz
# City not found. Skipping...
# Processing Record 49 of Set 5 | medicina
# Processing Record 50 of Set 5 | twin falls
# Processing Record 1 of Set 6 | lavrentiya
# Processing Record 2 of Set 6 | smithers
# Processing Record 3 of Set 6 | ixtapa
# Processing Record 4 of Set 6 | alofi
# Processing Record 5 of Set 6 | mount isa
# Processing Record 6 of Set 6 | sembe
# Processing Record 7 of Set 6 | krasnoselkup
# Processing Record 8 of Set 6 | clyde river
# Processing Record 9 of Set 6 | easley
# Processing Record 10 of Set 6 | bambous virieux
# Processing Record 11 of Set 6 | ancud
# Processing Record 12 of Set 6 | longyearbyen
# Processing Record 13 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 6 | pundaguitan
# Processing Record 15 of Set 6 | nikolskoye
# Processing Record 16 of Set 6 | nome
# Processing Record 17 of Set 6 | pocone
# Processing Record 18 of Set 6 | poum
# Processing Record 19 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 20 of Set 6 | castro
# Processing Record 21 of Set 6 | tricase
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 6 | neuquen
# Processing Record 25 of Set 6 | mao
# Processing Record 26 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 27 of Set 6 | thompson
# Processing Record 28 of Set 6 | bagdarin
# Processing Record 29 of Set 6 | saint george
# Processing Record 30 of Set 6 | mangrol
# Processing Record 31 of Set 6 | saint-philippe
# Processing Record 32 of Set 6 | filingue
# Processing Record 33 of Set 6 | waingapu
# Processing Record 34 of Set 6 | sandnessjoen
# Processing Record 35 of Set 6 | santa cruz cabralia
# Processing Record 36 of Set 6 | mayo
# Processing Record 37 of Set 6 | crateus
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | myitkyina
# Processing Record 40 of Set 6 | obala
# Processing Record 41 of Set 6 | walvis bay
# Processing Record 42 of Set 6 | rodrigues alves
# Processing Record 43 of Set 6 | ternate
# Processing Record 44 of Set 6 | cidreira
# Processing Record 45 of Set 6 | kaitangata
# Processing Record 46 of Set 6 | hermosillo
# Processing Record 47 of Set 6 | kabare
# Processing Record 48 of Set 6 | saryozek
# Processing Record 49 of Set 6 | meulaboh
# Processing Record 50 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 7 | svetlogorsk
# Processing Record 2 of Set 7 | rach gia
# Processing Record 3 of Set 7 | telma
# Processing Record 4 of Set 7 | alyangula
# Processing Record 5 of Set 7 | namatanai
# Processing Record 6 of Set 7 | qafsah
# City not found. Skipping...
# Processing Record 7 of Set 7 | sarapulka
# Processing Record 8 of Set 7 | morondava
# Processing Record 9 of Set 7 | kruisfontein
# Processing Record 10 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 7 | safaqis
# City not found. Skipping...
# Processing Record 12 of Set 7 | wilmington
# Processing Record 13 of Set 7 | constitucion
# Processing Record 14 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 15 of Set 7 | yumen
# Processing Record 16 of Set 7 | sungaipenuh
# Processing Record 17 of Set 7 | haines junction
# Processing Record 18 of Set 7 | akaltara
# Processing Record 19 of Set 7 | lamballe
# Processing Record 20 of Set 7 | evensk
# Processing Record 21 of Set 7 | hambantota
# Processing Record 22 of Set 7 | lipari
# Processing Record 23 of Set 7 | salinopolis
# Processing Record 24 of Set 7 | havoysund
# Processing Record 25 of Set 7 | novopokrovskaya
# Processing Record 26 of Set 7 | salalah
# Processing Record 27 of Set 7 | arroio grande
# Processing Record 28 of Set 7 | hofn
# Processing Record 29 of Set 7 | taiyuan
# Processing Record 30 of Set 7 | turukhansk
# Processing Record 31 of Set 7 | rondonopolis
# Processing Record 32 of Set 7 | saldanha
# Processing Record 33 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 7 | faanui
# Processing Record 35 of Set 7 | lafia
# Processing Record 36 of Set 7 | cabo san lucas
# Processing Record 37 of Set 7 | nieuwpoort
# Processing Record 38 of Set 7 | pochutla
# Processing Record 39 of Set 7 | wyndham
# Processing Record 40 of Set 7 | berdigestyakh
# Processing Record 41 of Set 7 | lewiston
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | comodoro rivadavia
# Processing Record 44 of Set 7 | kavaratti
# Processing Record 45 of Set 7 | pemberton
# Processing Record 46 of Set 7 | bubaque
# Processing Record 47 of Set 7 | xining
# Processing Record 48 of Set 7 | acton
# Processing Record 49 of Set 7 | tecpan
# Processing Record 50 of Set 7 | kailua
# Processing Record 1 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 8 | hervey bay
# Processing Record 4 of Set 8 | kurumkan
# Processing Record 5 of Set 8 | mackenzie
# Processing Record 6 of Set 8 | chicama
# Processing Record 7 of Set 8 | abaetetuba
# Processing Record 8 of Set 8 | homnabad
# Processing Record 9 of Set 8 | orje
# Processing Record 10 of Set 8 | broken hill
# Processing Record 11 of Set 8 | codrington
# Processing Record 12 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 8 | dauphin
# Processing Record 14 of Set 8 | rosetown
# Processing Record 15 of Set 8 | natal
# Processing Record 16 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 17 of Set 8 | margate
# Processing Record 18 of Set 8 | ilovlya
# Processing Record 19 of Set 8 | verkhniye kigi
# Processing Record 20 of Set 8 | itoman
# Processing Record 21 of Set 8 | bandarbeyla
# Processing Record 22 of Set 8 | quang ngai
# Processing Record 23 of Set 8 | talaya
# Processing Record 24 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 8 | mitsamiouli
# Processing Record 26 of Set 8 | tagusao
# Processing Record 27 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 28 of Set 8 | harper
# Processing Record 29 of Set 8 | casablanca
# Processing Record 30 of Set 8 | muros
# Processing Record 31 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 8 | awbari
# Processing Record 33 of Set 8 | tilichiki
# Processing Record 34 of Set 8 | ihosy
# Processing Record 35 of Set 8 | lorengau
# Processing Record 36 of Set 8 | puerto narino
# Processing Record 37 of Set 8 | bhadreswar
# Processing Record 38 of Set 8 | praia
# Processing Record 39 of Set 8 | sobolevo
# Processing Record 40 of Set 8 | mandali
# Processing Record 41 of Set 8 | banda aceh
# Processing Record 42 of Set 8 | mudyuga
# City not found. Skipping...
# Processing Record 43 of Set 8 | bela vista de goias
# Processing Record 44 of Set 8 | port lincoln
# Processing Record 45 of Set 8 | chake chake
# Processing Record 46 of Set 8 | puerto rico
# Processing Record 47 of Set 8 | randolph
# Processing Record 48 of Set 8 | bethel
# Processing Record 49 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 50 of Set 8 | yerbogachen
# Processing Record 1 of Set 9 | mayumba
# Processing Record 2 of Set 9 | vallenar
# Processing Record 3 of Set 9 | kommunisticheskiy
# Processing Record 4 of Set 9 | dolinsk
# Processing Record 5 of Set 9 | eureka
# Processing Record 6 of Set 9 | tiznit
# Processing Record 7 of Set 9 | noumea
# Processing Record 8 of Set 9 | kalmunai
# Processing Record 9 of Set 9 | karasburg
# Processing Record 10 of Set 9 | praia da vitoria
# Processing Record 11 of Set 9 | maniwaki
# Processing Record 12 of Set 9 | nemuro
# Processing Record 13 of Set 9 | sladkovo
# Processing Record 14 of Set 9 | bilibino
# Processing Record 15 of Set 9 | port hardy
# Processing Record 16 of Set 9 | thinadhoo
# Processing Record 17 of Set 9 | tukan
# Processing Record 18 of Set 9 | kapit
# Processing Record 19 of Set 9 | chapais
# Processing Record 20 of Set 9 | mpika
# Processing Record 21 of Set 9 | carpentras
# Processing Record 22 of Set 9 | preobrazheniye
# Processing Record 23 of Set 9 | atocha
# Processing Record 24 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 9 | corn island
# Processing Record 26 of Set 9 | soe
# Processing Record 27 of Set 9 | portland
# Processing Record 28 of Set 9 | laguna
# Processing Record 29 of Set 9 | najibabad
# Processing Record 30 of Set 9 | abu samrah
# Processing Record 31 of Set 9 | kungurtug
# Processing Record 32 of Set 9 | mackay
# Processing Record 33 of Set 9 | omsukchan
# Processing Record 34 of Set 9 | ponta delgada
# Processing Record 35 of Set 9 | stavyshche
# Processing Record 36 of Set 9 | port blair
# Processing Record 37 of Set 9 | uvinza
# Processing Record 38 of Set 9 | rawson
# Processing Record 39 of Set 9 | mosetse
# Processing Record 40 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 41 of Set 9 | bazarnyye mataki
# Processing Record 42 of Set 9 | aknada
# Processing Record 43 of Set 9 | berlevag
# Processing Record 44 of Set 9 | glossop
# Processing Record 45 of Set 9 | sao gabriel da cachoeira
# Processing Record 46 of Set 9 | malanje
# Processing Record 47 of Set 9 | tamiahua
# Processing Record 48 of Set 9 | hakvik
# City not found. Skipping...
# Processing Record 49 of Set 9 | sturgeon falls
# Processing Record 50 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 10 | moerai
# Processing Record 2 of Set 10 | chumikan
# Processing Record 3 of Set 10 | linqiong
# Processing Record 4 of Set 10 | taltal
# Processing Record 5 of Set 10 | northam
# Processing Record 6 of Set 10 | kununurra
# Processing Record 7 of Set 10 | bulawayo
# Processing Record 8 of Set 10 | linchuan
# City not found. Skipping...
# Processing Record 9 of Set 10 | atar
# Processing Record 10 of Set 10 | victor harbor
# Processing Record 11 of Set 10 | jiangyou
# Processing Record 12 of Set 10 | jomalig
# City not found. Skipping...
# Processing Record 13 of Set 10 | jalu
# Processing Record 14 of Set 10 | nan
# Processing Record 15 of Set 10 | acapulco
# Processing Record 16 of Set 10 | kattivakkam
# Processing Record 17 of Set 10 | mahuva
# Processing Record 18 of Set 10 | kalispell
# Processing Record 19 of Set 10 | bardiyah
# Processing Record 20 of Set 10 | doha
# Processing Record 21 of Set 10 | karpathos
# Processing Record 22 of Set 10 | beloha
# Processing Record 23 of Set 10 | roswell
# Processing Record 24 of Set 10 | arroyo grande
# Processing Record 25 of Set 10 | egvekinot
# Processing Record 26 of Set 10 | el jicaro
# Processing Record 27 of Set 10 | saint-joseph
# Processing Record 28 of Set 10 | roald
# Processing Record 29 of Set 10 | nishihara
# Processing Record 30 of Set 10 | floro
# Processing Record 31 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 32 of Set 10 | mae sai
# Processing Record 33 of Set 10 | zhigansk
# Processing Record 34 of Set 10 | granadilla de abona
# Processing Record 35 of Set 10 | kenscoff
# Processing Record 36 of Set 10 | sao filipe
# Processing Record 37 of Set 10 | bjorkelangen
# Processing Record 38 of Set 10 | tres palos
# Processing Record 39 of Set 10 | quatre cocos
# Processing Record 40 of Set 10 | narsaq
# Processing Record 41 of Set 10 | najran
# Processing Record 42 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 10 | morant bay
# Processing Record 44 of Set 10 | qaqortoq
# Processing Record 45 of Set 10 | mina
# Processing Record 46 of Set 10 | cayenne
# Processing Record 47 of Set 10 | husavik
# Processing Record 48 of Set 10 | jesenice
# Processing Record 49 of Set 10 | namibe
# Processing Record 50 of Set 10 | yining
# Processing Record 1 of Set 11 | whyalla
# Processing Record 2 of Set 11 | chute-aux-outardes
# Processing Record 3 of Set 11 | gigmoto
# Processing Record 4 of Set 11 | sao joao da barra
# Processing Record 5 of Set 11 | dangriga
# Processing Record 6 of Set 11 | lewistown
# Processing Record 7 of Set 11 | calama
# Processing Record 8 of Set 11 | sain alto
# Processing Record 9 of Set 11 | zhangjiakou
# Processing Record 10 of Set 11 | awjilah
# Processing Record 11 of Set 11 | padang
# Processing Record 12 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 11 | fairview
# Processing Record 14 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 15 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 11 | kenai
# Processing Record 17 of Set 11 | loukhi
# Processing Record 18 of Set 11 | berbera
# Processing Record 19 of Set 11 | palmerston
# Processing Record 20 of Set 11 | jumla
# Processing Record 21 of Set 11 | seddon
# Processing Record 22 of Set 11 | kota
# Processing Record 23 of Set 11 | okhotsk
# Processing Record 24 of Set 11 | pitimbu
# Processing Record 25 of Set 11 | san marcos
# Processing Record 26 of Set 11 | tanjong tokong
# City not found. Skipping...
# Processing Record 27 of Set 11 | playa del carmen
# Processing Record 28 of Set 11 | bandar-e lengeh
# Processing Record 29 of Set 11 | sanandaj
# Processing Record 30 of Set 11 | naze
# Processing Record 31 of Set 11 | mago
# Processing Record 32 of Set 11 | benguela
# Processing Record 33 of Set 11 | yanji
# Processing Record 34 of Set 11 | ampanihy
# Processing Record 35 of Set 11 | voi
# Processing Record 36 of Set 11 | cam ranh
# Processing Record 37 of Set 11 | houma
# Processing Record 38 of Set 11 | san jose
# Processing Record 39 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 11 | hobyo
# Processing Record 41 of Set 11 | amahai
# Processing Record 42 of Set 11 | tolbazy
# Processing Record 43 of Set 11 | puerto escondido
# Processing Record 44 of Set 11 | vangaindrano
# Processing Record 45 of Set 11 | brasilia
# Processing Record 46 of Set 11 | taseyevo
# Processing Record 47 of Set 11 | los llanos de aridane
# Processing Record 48 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 11 | bam
# Processing Record 50 of Set 11 | brus laguna
# Processing Record 1 of Set 12 | dinghai
# Processing Record 2 of Set 12 | touros
# Processing Record 3 of Set 12 | sabha
# Processing Record 4 of Set 12 | cotui
# Processing Record 5 of Set 12 | hirado
# Processing Record 6 of Set 12 | ola
# Processing Record 7 of Set 12 | ketchikan
# Processing Record 8 of Set 12 | belyy yar
# Processing Record 9 of Set 12 | maceio
# Processing Record 10 of Set 12 | qandala
# Processing Record 11 of Set 12 | mazagao
# Processing Record 12 of Set 12 | aklavik
# Processing Record 13 of Set 12 | san javier
# Processing Record 14 of Set 12 | solnechnyy
# Processing Record 15 of Set 12 | roma
# Processing Record 16 of Set 12 | lasa
# Processing Record 17 of Set 12 | varkaus
# Processing Record 18 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 12 | springbok
# Processing Record 20 of Set 12 | san ramon
# Processing Record 21 of Set 12 | texarkana
# Processing Record 22 of Set 12 | rio cuarto
# Processing Record 23 of Set 12 | santa cruz
# Processing Record 24 of Set 12 | shelburne
# Processing Record 25 of Set 12 | plainview
# Processing Record 26 of Set 12 | teguise
# Processing Record 27 of Set 12 | mahibadhoo
# Processing Record 28 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 12 | siedlce
# Processing Record 30 of Set 12 | payo
# Processing Record 31 of Set 12 | nador
# Processing Record 32 of Set 12 | riacho de santana
# Processing Record 33 of Set 12 | manhattan
# Processing Record 34 of Set 12 | sakaiminato
# Processing Record 35 of Set 12 | olga
# Processing Record 36 of Set 12 | cockburn town
# Processing Record 37 of Set 12 | adwa
# Processing Record 38 of Set 12 | ilhabela
# Processing Record 39 of Set 12 | eyl
# Processing Record 40 of Set 12 | iquique
# Processing Record 41 of Set 12 | sredec
# City not found. Skipping...
# Processing Record 42 of Set 12 | berthierville
# Processing Record 43 of Set 12 | college
# Processing Record 44 of Set 12 | bijar
# Processing Record 45 of Set 12 | tessalit
# Processing Record 46 of Set 12 | huangpi
# Processing Record 47 of Set 12 | tefe
# Processing Record 48 of Set 12 | okha
# Processing Record 49 of Set 12 | khash
# Processing Record 50 of Set 12 | barsinghausen
# Processing Record 1 of Set 13 | pala
# Processing Record 2 of Set 13 | shangqiu
# Processing Record 3 of Set 13 | mato verde
# Processing Record 4 of Set 13 | fuyu
# Processing Record 5 of Set 13 | riyadh
# Processing Record 6 of Set 13 | katangli
# Processing Record 7 of Set 13 | buala
# Processing Record 8 of Set 13 | shimoda
# Processing Record 9 of Set 13 | ronneby
# Processing Record 10 of Set 13 | vilhena
# Processing Record 11 of Set 13 | fayaoue
# Processing Record 12 of Set 13 | inhambane
# Processing Record 13 of Set 13 | ugoofaaru
# Processing Record 14 of Set 13 | kudahuvadhoo
# Processing Record 15 of Set 13 | voyvozh
# Processing Record 16 of Set 13 | zheleznodorozhnyy
# Processing Record 17 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 13 | pascagoula
# Processing Record 19 of Set 13 | norman wells
# Processing Record 20 of Set 13 | baruun-urt
# Processing Record 21 of Set 13 | gat
# Processing Record 22 of Set 13 | kaeo
# Processing Record 23 of Set 13 | boguchany
# Processing Record 24 of Set 13 | marzuq
# Processing Record 25 of Set 13 | auki
# Processing Record 26 of Set 13 | puerto carreno
# Processing Record 27 of Set 13 | caravelas
# Processing Record 28 of Set 13 | hereford
# Processing Record 29 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 13 | san rafael
# Processing Record 31 of Set 13 | ukmerge
# Processing Record 32 of Set 13 | sasvad
# Processing Record 33 of Set 13 | sechura
# Processing Record 34 of Set 13 | terrak
# Processing Record 35 of Set 13 | sakakah
# Processing Record 36 of Set 13 | auburn
# Processing Record 37 of Set 13 | villanueva de la serena
# Processing Record 38 of Set 13 | hauterive
# Processing Record 39 of Set 13 | nkhata bay
# Processing Record 40 of Set 13 | coshocton
# Processing Record 41 of Set 13 | khanion tou kokkini
# City not found. Skipping...
# Processing Record 42 of Set 13 | leh
# Processing Record 43 of Set 13 | guaraniacu
# Processing Record 44 of Set 13 | havre
# Processing Record 45 of Set 13 | krasne
# Processing Record 46 of Set 13 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 13 | churapcha
# Processing Record 48 of Set 13 | quime
# Processing Record 49 of Set 13 | williams lake
# Processing Record 50 of Set 13 | coahuayana
# Processing Record 1 of Set 14 | quchan
# Processing Record 2 of Set 14 | veshenskaya
# Processing Record 3 of Set 14 | kotaparh
# Processing Record 4 of Set 14 | batticaloa
# Processing Record 5 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 14 | otane
# Processing Record 7 of Set 14 | havre-saint-pierre
# Processing Record 8 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 14 | bonthe
# Processing Record 10 of Set 14 | wukari
# Processing Record 11 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 14 | fria
# Processing Record 13 of Set 14 | caloundra
# Processing Record 14 of Set 14 | inta
# Processing Record 15 of Set 14 | biloela
# Processing Record 16 of Set 14 | kuah
# Processing Record 17 of Set 14 | sainte-anne-des-monts
# Processing Record 18 of Set 14 | farah
# Processing Record 19 of Set 14 | kysyl-syr
# Processing Record 20 of Set 14 | sioux lookout
# Processing Record 21 of Set 14 | santa rita
# Processing Record 22 of Set 14 | fallon
# Processing Record 23 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 14 | kanigoro
# Processing Record 25 of Set 14 | puerto del rosario
# Processing Record 26 of Set 14 | manokwari
# Processing Record 27 of Set 14 | linjiang
# Processing Record 28 of Set 14 | sinnamary
# Processing Record 29 of Set 14 | poltavka
# Processing Record 30 of Set 14 | tambo
# Processing Record 31 of Set 14 | humaita
# Processing Record 32 of Set 14 | hirara
# Processing Record 33 of Set 14 | honningsvag
# Processing Record 34 of Set 14 | the valley
# Processing Record 35 of Set 14 | nancha
# Processing Record 36 of Set 14 | lata
# Processing Record 37 of Set 14 | dafeng
# Processing Record 38 of Set 14 | vestmanna
# Processing Record 39 of Set 14 | moba
# Processing Record 40 of Set 14 | wareham
# Processing Record 41 of Set 14 | muroto
# Processing Record 42 of Set 14 | primorsko
# Processing Record 43 of Set 14 | hachinohe
# Processing Record 44 of Set 14 | acarau
# Processing Record 45 of Set 14 | piacabucu
# Processing Record 46 of Set 14 | say
# Processing Record 47 of Set 14 | stephenville
# Processing Record 48 of Set 14 | uppsala
# Processing Record 49 of Set 14 | kumla
# Processing Record 50 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 1 of Set 15 | arlit
# Processing Record 2 of Set 15 | garowe
# Processing Record 3 of Set 15 | japura
# Processing Record 4 of Set 15 | dekoa
# City not found. Skipping...
# Processing Record 5 of Set 15 | bertrix
# Processing Record 6 of Set 15 | dekar
# Processing Record 7 of Set 15 | bulgan
# Processing Record 8 of Set 15 | ninohe
# Processing Record 9 of Set 15 | rocha
# Processing Record 10 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 12 of Set 15 | cafarnaum
# Processing Record 13 of Set 15 | mpongwe
# Processing Record 14 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 15 | talnakh
# Processing Record 16 of Set 15 | seoul
# Processing Record 17 of Set 15 | brattvag
# Processing Record 18 of Set 15 | abu dhabi
# Processing Record 19 of Set 15 | saint paul
# Processing Record 20 of Set 15 | misratah
# Processing Record 21 of Set 15 | faya
# Processing Record 22 of Set 15 | kuching
# Processing Record 23 of Set 15 | pemangkat
# Processing Record 24 of Set 15 | kaniama
# Processing Record 25 of Set 15 | katsuura
# Processing Record 26 of Set 15 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 15 | la union
# Processing Record 28 of Set 15 | moron
# Processing Record 29 of Set 15 | cootamundra
# Processing Record 30 of Set 15 | lapua
# Processing Record 31 of Set 15 | inongo
# Processing Record 32 of Set 15 | lazarev
# Processing Record 33 of Set 15 | mlimba
# Processing Record 34 of Set 15 | isabela
# Processing Record 35 of Set 15 | bol
# Processing Record 36 of Set 15 | port keats
# Processing Record 37 of Set 15 | vila velha
# Processing Record 38 of Set 15 | achit
# Processing Record 39 of Set 15 | leghorn
# City not found. Skipping...
# Processing Record 40 of Set 15 | grimshaw
# Processing Record 41 of Set 15 | hvide sande
# Processing Record 42 of Set 15 | marrakesh
# Processing Record 43 of Set 15 | xuddur
# Processing Record 44 of Set 15 | takoradi
# Processing Record 45 of Set 15 | angoche
# Processing Record 46 of Set 15 | champerico
# Processing Record 47 of Set 15 | ambanja
# Processing Record 48 of Set 15 | arrifes
# Processing Record 49 of Set 15 | adre
# Processing Record 50 of Set 15 | gedo
# Processing Record 1 of Set 16 | ranong
# Processing Record 2 of Set 16 | ozernovskiy
# Processing Record 3 of Set 16 | krasnyy yar
# Processing Record 4 of Set 16 | marsabit
# Processing Record 5 of Set 16 | geresk
# City not found. Skipping...
# Processing Record 6 of Set 16 | antalaha
# Processing Record 7 of Set 16 | aitape
# Processing Record 8 of Set 16 | maracacume
# Processing Record 9 of Set 16 | radyvyliv
# Processing Record 10 of Set 16 | richmond
# Processing Record 11 of Set 16 | yarada
# Processing Record 12 of Set 16 | pimentel
# Processing Record 13 of Set 16 | ewa beach
# Processing Record 14 of Set 16 | mwinilunga
# Processing Record 15 of Set 16 | bani walid
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 695

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vardo  70.3705   31.1107     53.35        81           0
# 1         Pandan  14.0453  124.1694     82.96        76         100
# 2        Manyana -23.4000   21.7167     60.82        20           0
# 3        Balabac   7.9868  117.0645     83.88        78         100
# 4       Hokitika -42.7167  170.9667     46.67        89         100
# 5  San Cristobal   7.7669  -72.2250     80.78        70         100
# 6          Vaini -21.2000 -175.2000     68.16        77          20
# 7         Barrow  71.2906 -156.7887     44.62        81          90
# 8        Ushuaia -54.8000  -68.3000     46.06        53          40
# 9     Nanortalik  60.1432  -45.2371     46.92        85          91
#
#    Wind Speed Country                 Date Current Description
# 0        2.30      NO  2021-08-02 16:48:43           clear sky
# 1       14.52      PH  2021-08-02 16:48:43     overcast clouds
# 2        6.17      BW  2021-08-02 16:48:44           clear sky
# 3       16.89      PH  2021-08-02 16:48:44     overcast clouds
# 4        9.46      NZ  2021-08-02 16:48:45          light rain
# 5        7.74      VE  2021-08-02 16:48:45     overcast clouds
# 6       10.36      TO  2021-08-02 16:48:45          few clouds
# 7       10.36      US  2021-08-02 16:48:46     overcast clouds
# 8        4.61      AR  2021-08-02 16:48:46          light rain
# 9        2.68      GL  2021-08-02 16:48:47     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Vardo      NO  70.3705   31.1107     53.35        81           0
# 1         Pandan      PH  14.0453  124.1694     82.96        76         100
# 2        Manyana      BW -23.4000   21.7167     60.82        20           0
# 3        Balabac      PH   7.9868  117.0645     83.88        78         100
# 4       Hokitika      NZ -42.7167  170.9667     46.67        89         100
# 5  San Cristobal      VE   7.7669  -72.2250     80.78        70         100
# 6          Vaini      TO -21.2000 -175.2000     68.16        77          20
# 7         Barrow      US  71.2906 -156.7887     44.62        81          90
# 8        Ushuaia      AR -54.8000  -68.3000     46.06        53          40
# 9     Nanortalik      GL  60.1432  -45.2371     46.92        85          91
#
#    Wind Speed Current Description
# 0        2.30           clear sky
# 1       14.52     overcast clouds
# 2        6.17           clear sky
# 3       16.89     overcast clouds
# 4        9.46          light rain
# 5        7.74     overcast clouds
# 6       10.36          few clouds
# 7       10.36     overcast clouds
# 8        4.61          light rain
# 9        2.68     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
